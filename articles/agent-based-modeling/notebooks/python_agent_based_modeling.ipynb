# %% [markdown]
# # Agent-Based Modeling
#
# Notebook-ready companion for `python/agent_based_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare local interaction, satisfaction, clustering, and final grid diagnostics.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
