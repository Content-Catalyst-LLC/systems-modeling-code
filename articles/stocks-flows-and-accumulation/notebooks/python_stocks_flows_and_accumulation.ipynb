# %% [markdown]
# # Stocks, Flows, and Accumulation
#
# Notebook-ready companion for `python/stock_flow_accumulation_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare backlog, resource, and infrastructure condition trajectories across baseline, delayed response, capacity, stress, and adaptive recovery scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
