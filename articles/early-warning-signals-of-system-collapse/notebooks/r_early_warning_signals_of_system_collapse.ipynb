# %% [markdown]
# # R Early Warning Signal Diagnostics
#
# Notebook-ready placeholder for the base R early-warning diagnostics workflow.
#
# Run `r/early_warning_signals_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
