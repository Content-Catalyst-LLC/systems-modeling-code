# %% [markdown]
# # Early Warning Signals of System Collapse
#
# Notebook-ready companion for `python/early_warning_signals_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare baseline destabilization, moderate destabilization, high noise, low noise, short-window, long-window, rapid-destabilization, and slow-destabilization scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
