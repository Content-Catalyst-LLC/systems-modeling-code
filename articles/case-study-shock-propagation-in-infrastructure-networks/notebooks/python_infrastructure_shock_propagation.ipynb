# %% [markdown]
# # Case Study: Shock Propagation in Infrastructure Networks
#
# Notebook-ready companion for `python/infrastructure_shock_propagation_workflow.py`.
#
# Run the Python workflow, then inspect CSV outputs in `outputs/tables/`.
