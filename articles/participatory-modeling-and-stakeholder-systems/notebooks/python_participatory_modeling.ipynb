# %% [markdown]
# # Participatory Modeling and Stakeholder Systems
#
# Notebook-ready companion for `python/participatory_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare stakeholder scores, disagreement diagnostics, assumption status, and legitimacy-adjusted rankings.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
