# %% [markdown]
# # R Participatory Modeling Workflow
#
# Notebook-ready placeholder for the base R stakeholder scoring and consensus workflow.
#
# Run `r/participatory_modeling_workflow.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
