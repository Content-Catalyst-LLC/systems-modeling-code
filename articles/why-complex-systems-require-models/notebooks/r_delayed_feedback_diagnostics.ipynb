# %% [markdown]
# # R Delayed Feedback Diagnostics
#
# Notebook-ready placeholder for the R workflow.
#
# Run `r/why_complex_systems_require_models_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
