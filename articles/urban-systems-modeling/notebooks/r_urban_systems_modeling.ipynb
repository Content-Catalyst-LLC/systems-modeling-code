# %% [markdown]
# # R Urban Systems Growth Feedback Diagnostics
#
# Notebook-ready placeholder for the base R urban growth and congestion feedback workflow.
#
# Run `r/urban_systems_growth_feedback_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
