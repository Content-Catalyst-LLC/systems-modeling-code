# %% [markdown]
# # R Uncertainty Interpretation Diagnostics
#
# Notebook-ready placeholder for the base R Monte Carlo uncertainty propagation workflow.
#
# Run `r/uncertainty_interpretation_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
