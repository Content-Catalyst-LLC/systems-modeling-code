# %% [markdown]
# # Ethics, Power, and Systems Modeling
#
# Notebook-ready companion for `python/ethics_power_systems_modeling_workflow.py`.
#
# Run the Python script, then inspect outputs in `outputs/tables/`.
