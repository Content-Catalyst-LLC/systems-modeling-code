# %% [markdown]
# # Resilience and Adaptive Systems
# Notebook-ready companion for `python/resilience_adaptive_systems_workflow.py`.

# %%
from pathlib import Path
tables = Path.cwd() / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
