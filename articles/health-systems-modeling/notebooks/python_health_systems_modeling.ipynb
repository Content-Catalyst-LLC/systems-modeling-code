# %% [markdown]
# # Health Systems Modeling
#
# Notebook-ready companion for `python/health_systems_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare baseline health system, higher demand growth, stronger prevention, larger surge, faster hiring, higher access barrier, burnout-sensitive, and resilient prepared system scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
