# %% [markdown]
# # Case Study: Resilience Modeling Under Climate Stress
#
# Notebook-ready companion for `python/climate_resilience_scenario_workflow.py`.
#
# Run the Python workflow, then inspect CSV outputs in `outputs/tables/`.
