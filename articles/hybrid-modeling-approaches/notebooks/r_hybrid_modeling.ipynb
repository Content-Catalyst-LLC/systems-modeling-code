# %% [markdown]
# # R Hybrid Modeling Diagnostics
#
# Notebook-ready placeholder for the base R aggregate-agent feedback workflow.
#
# Run `r/hybrid_modeling_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
