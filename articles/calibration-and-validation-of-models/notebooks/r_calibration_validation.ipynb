# %% [markdown]
# # R Calibration and Validation Diagnostics
#
# Notebook-ready placeholder for the base R calibration and out-of-sample validation workflow.
#
# Run `r/calibration_validation_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
