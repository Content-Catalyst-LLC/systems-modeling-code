# %% [markdown]
# # Case Study: Agent-Based Modeling of Adoption and Diffusion
#
# Notebook-ready companion for `python/agent_based_adoption_diffusion_workflow.py`.
#
# Run the Python workflow, then inspect CSV outputs in `outputs/tables/`.
