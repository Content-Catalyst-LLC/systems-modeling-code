# %% [markdown]
# # Systems Thinking vs Systems Modeling
#
# Notebook-ready companion for `python/systems_thinking_vs_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare conceptual systems scores with modeled systems scores.
# 4. Inspect sensitivity diagnostics and validation outputs.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
