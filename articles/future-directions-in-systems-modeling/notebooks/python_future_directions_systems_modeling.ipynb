# %% [markdown]
# # Future Directions in Systems Modeling
#
# Notebook-ready companion for `python/future_directions_systems_modeling_workflow.py`.
#
# Run the Python script, then inspect outputs in `outputs/tables/`.
