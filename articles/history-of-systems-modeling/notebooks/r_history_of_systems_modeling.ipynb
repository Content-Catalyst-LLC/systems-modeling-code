# %% [markdown]
# # R Historical Systems Modeling Diagnostics
#
# Notebook-ready placeholder for the base R workflow.
#
# Run `r/history_of_systems_modeling_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
