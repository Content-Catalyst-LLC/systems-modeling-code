# %% [markdown]
# # R Organizational Workload-Capacity Diagnostics
#
# Notebook-ready placeholder for the base R organizational workload-capacity workflow.
#
# Run `r/organizational_workload_capacity_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
