# %% [markdown]
# # R Geospatial Systems Modeling Workflow
#
# Notebook-ready placeholder for the base R grid-based exposure and accessibility workflow.
#
# Run `r/geospatial_systems_modeling_workflow.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
