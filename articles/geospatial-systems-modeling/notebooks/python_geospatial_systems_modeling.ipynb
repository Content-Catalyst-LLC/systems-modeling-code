# %% [markdown]
# # Geospatial Systems Modeling
#
# Notebook-ready companion for `python/geospatial_systems_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare baseline, higher hazard, high vulnerability, low access, population growth, and resilient service scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
