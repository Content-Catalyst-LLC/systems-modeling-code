# %% [markdown]
# # Mathematics of Complex Systems
#
# Notebook-ready companion for `python/mathematics_complex_systems_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare nonlinear trajectory divergence, bifurcation samples, network diffusion trajectories, entropy, and dispersion diagnostics.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
