# %% [markdown]
# # R Core Principles Diagnostics
#
# Notebook-ready placeholder for the base R workflow.
#
# Run `r/core_principles_systems_modeling_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
