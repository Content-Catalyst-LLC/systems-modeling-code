# %% [markdown]
# # R Delay, Oscillation, and Policy Resistance Diagnostics
#
# Notebook-ready placeholder for the base R delayed-feedback diagnostics workflow.
#
# Run `r/delay_oscillation_policy_resistance_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
