# %% [markdown]
# # Integrated Assessment Models
# Notebook-ready companion for `python/integrated_assessment_models_workflow.py`.

# %%
from pathlib import Path
tables = Path('outputs/tables')
list(tables.glob('*.csv'))[:10]
