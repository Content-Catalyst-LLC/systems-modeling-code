# %% [markdown]
# # AI and Machine Learning in Systems Modeling
#
# Notebook-ready companion for `python/ai_ml_systems_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare structural baseline, hybrid residual-learning, data-risk, governance, and validation outputs.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
