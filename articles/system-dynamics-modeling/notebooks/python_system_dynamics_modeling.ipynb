# %% [markdown]
# # System Dynamics Modeling
#
# Notebook-ready companion for `python/system_dynamics_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare stock-flow, feedback, delay, threshold, scenario, and sensitivity diagnostics.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
