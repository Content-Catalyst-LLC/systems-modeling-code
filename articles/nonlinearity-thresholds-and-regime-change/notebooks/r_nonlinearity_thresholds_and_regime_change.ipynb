# %% [markdown]
# # R Nonlinearity, Threshold, and Regime-Change Diagnostics
#
# Notebook-ready placeholder for the base R nonlinear threshold diagnostics workflow.
#
# Run `r/nonlinearity_threshold_regime_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
