# %% [markdown]
# # Nonlinearity, Thresholds, and Regime Change
#
# Notebook-ready companion for `python/nonlinearity_threshold_regime_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare early intervention, late intervention, strong recovery, lower-threshold stress, hysteresis trap, and rapid prevention scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
