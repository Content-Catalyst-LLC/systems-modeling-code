# %% [markdown]
# # R Leverage Points Intervention Diagnostics
#
# Notebook-ready placeholder for the base R intervention-depth diagnostics workflow.
#
# Run `r/leverage_points_intervention_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
