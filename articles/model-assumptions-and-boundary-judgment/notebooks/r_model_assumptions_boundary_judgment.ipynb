# %% [markdown]
# # R Assumption and Boundary Judgment Workflow
#
# Notebook-ready placeholder for the base R assumption risk and boundary comparison workflow.
#
# Run `r/model_assumptions_boundary_judgment_workflow.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
