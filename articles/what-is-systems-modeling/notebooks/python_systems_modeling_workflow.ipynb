# %% [markdown]
# # Systems Modeling Workflow
#
# Notebook-ready companion for `python/systems_modeling_professional_workflow.py`.
#
# Suggested steps:
#
# 1. Run the Python workflow.
# 2. Load generated CSV files from `outputs/tables/`.
# 3. Visualize network scenario summaries, node vulnerability, and stock-flow sensitivity.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
