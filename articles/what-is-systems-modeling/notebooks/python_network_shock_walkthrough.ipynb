# %% [markdown]
# # Python Network Shock Walkthrough
#
# Notebook-ready placeholder for the systems modeling article companion folder.
#
# Suggested use: import `python/network_shock_propagation.py`, run scenarios, and visualize node trajectories.

# %%
from pathlib import Path
article_root = Path.cwd()
article_root
