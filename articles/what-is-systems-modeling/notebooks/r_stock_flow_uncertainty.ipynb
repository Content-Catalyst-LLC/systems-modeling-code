# %% [markdown]
# # R Stock-Flow Uncertainty Workflow
#
# Notebook-ready placeholder for the base R stock-flow uncertainty workflow.
#
# Run `r/stock_flow_uncertainty_workflow.R`, then inspect generated outputs in `outputs/tables/` and `outputs/figures/`.
