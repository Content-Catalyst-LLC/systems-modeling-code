# %% [markdown]
# # R Environmental Systems Resource Recovery Diagnostics
#
# Notebook-ready placeholder for the base R environmental stock-flow workflow.
#
# Run `r/environmental_systems_resource_recovery_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
