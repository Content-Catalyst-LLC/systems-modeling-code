# %% [markdown]
# # Critical Transitions and Tipping Points in Complex Systems
#
# Notebook-ready companion for `python/critical_transitions_tipping_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare baseline hysteresis, slow forcing, fast forcing, wide forcing, near-threshold starting conditions, recovery stress, high-resolution forcing, and policy-delay scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
