# %% [markdown]
# # R Public Policy Delayed Response Diagnostics
#
# Notebook-ready placeholder for the base R public policy delayed response workflow.
#
# Run `r/public_policy_delayed_response_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
