# %% [markdown]
# # Discrete Event Simulation
#
# Notebook-ready companion for `python/discrete_event_simulation_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare event traces, entity traces, waiting times, utilization, and service-level diagnostics.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
