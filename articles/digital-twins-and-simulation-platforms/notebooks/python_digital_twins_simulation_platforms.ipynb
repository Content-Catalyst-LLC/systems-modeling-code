# %% [markdown]
# # Digital Twins and Simulation Platforms
#
# Notebook-ready companion for `python/digital_twins_simulation_platforms_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare baseline, high-noise, shock-heavy, slow-update, resilient, and sensor-drift twin scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
