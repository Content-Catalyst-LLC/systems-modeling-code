# %% [markdown]
# # When Systems Models Clarify and When They Distort
#
# Notebook-ready companion for `python/clarification_distortion_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Review clarification scores, distortion risk scores, model-use labels, communication controls, and scope-of-use registers.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
