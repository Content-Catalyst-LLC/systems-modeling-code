# %% [markdown]
# # R Clarification and Distortion Workflow
#
# Notebook-ready placeholder for the base R clarification value and distortion-risk workflow.
#
# Run `r/clarification_distortion_workflow.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
