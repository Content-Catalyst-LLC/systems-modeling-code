# %% [markdown]
# # Communicating Model Results Responsibly
#
# Notebook-ready companion for `python/communicating_model_results_responsibly_workflow.py`.
#
# Run the Python script, then inspect outputs in `outputs/tables/`.
