# %% [markdown]
# # R Communicating Model Results Responsibly Workflow
#
# Run `r/communicating_model_results_responsibly_workflow.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
