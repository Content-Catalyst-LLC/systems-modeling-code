# %% [markdown]
# # Scenario Modeling and Simulation
#
# Notebook-ready companion for `python/scenario_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare policy robustness, regret, worst-case outcomes, and scenario ensembles.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
