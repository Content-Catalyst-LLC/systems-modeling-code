# %% [markdown]
# # R Scenario Modeling Diagnostics
#
# Notebook-ready placeholder for the base R alternative-futures workflow.
#
# Run `r/scenario_modeling_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
