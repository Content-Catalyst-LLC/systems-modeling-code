# %% [markdown]
# # Case Study: Scenario Modeling for Public Policy
#
# Notebook-ready companion for `python/public_policy_scenario_modeling_workflow.py`.
#
# Run the Python workflow, then inspect CSV outputs in `outputs/tables/`.
