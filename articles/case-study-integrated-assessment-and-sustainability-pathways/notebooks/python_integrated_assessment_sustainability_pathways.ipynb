# %% [markdown]
# # Case Study: Integrated Assessment and Sustainability Pathways
#
# Notebook-ready companion for `python/integrated_assessment_sustainability_pathways_workflow.py`.
#
# Run the Python workflow, then inspect CSV outputs in `outputs/tables/`.
