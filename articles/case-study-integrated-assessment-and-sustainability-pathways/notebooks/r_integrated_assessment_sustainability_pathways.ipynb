# %% [markdown]
# # R Integrated Assessment and Sustainability Pathways Workflow
#
# Run `r/integrated_assessment_sustainability_pathways_workflow.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
