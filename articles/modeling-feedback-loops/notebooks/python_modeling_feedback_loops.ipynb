# %% [markdown]
# # Modeling Feedback Loops
#
# Notebook-ready companion for `python/feedback_loop_modeling_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare reinforcing, balancing, logistic, delayed, stock-flow, and policy-resistance feedback diagnostics.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
