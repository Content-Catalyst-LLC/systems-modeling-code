# %% [markdown]
# # R Sensitivity Analysis Diagnostics
#
# Notebook-ready placeholder for the base R local and global sensitivity workflow.
#
# Run `r/sensitivity_analysis_diagnostics.R`, then inspect outputs in `outputs/tables/` and `outputs/figures/`.
