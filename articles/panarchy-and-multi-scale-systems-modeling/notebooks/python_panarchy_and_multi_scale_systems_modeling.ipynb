# %% [markdown]
# # Panarchy and Multi-Scale Systems Modeling
#
# Notebook-ready companion for `python/panarchy_multiscale_systems_workflow.py`.
#
# Suggested workflow:
#
# 1. Run the Python script.
# 2. Load outputs from `outputs/tables/`.
# 3. Compare baseline panarchy, strong revolt, strong remember, rigid slow structure, weak memory/high volatility, adaptive transformation, locked conservation, and recurrent release scenarios.

# %%
from pathlib import Path
article_root = Path.cwd()
tables = article_root / 'outputs' / 'tables'
list(tables.glob('*.csv'))[:10]
