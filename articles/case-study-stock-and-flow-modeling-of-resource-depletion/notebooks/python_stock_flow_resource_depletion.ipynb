# %% [markdown]
# # Case Study: Stock-and-Flow Modeling of Resource Depletion
#
# Notebook-ready companion for `python/stock_flow_resource_depletion_workflow.py`.
#
# Run the Python workflow, then inspect CSV outputs in `outputs/tables/`.
